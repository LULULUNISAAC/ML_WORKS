# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %%
np.random.randn(10)

# %%
from numpy.random import default_rng
rng = default_rng(0)

rng.random(10)

# %%
np.random.seed(1)

df = pd.DataFrame({
    'Col_1': rng.random(10)*6-3,
    'Col_2': rng.random(10)*2500-500,
    'Col_3': rng.random(10)*2
})

df.head()
# Out:
#       Col_1        Col_2     Col_3
# 0  0.429179  1467.745769  0.809104
# 1 -1.068784    98.423607  0.397026
# 2  0.565800  1691.210577  0.181506
# 3 -0.972533  -353.579913  1.160665
# 4 -0.650286   340.292651  0.597392

# %% [markdown]
# # Standard Scaler
# ### xi-mean(x)/stdev(x)

# %%
# Your code
columns = df. columns
features = df

scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

scaled_features = pd.DataFrame(features, columns = columns)
scaled_features.head()
# Out:
#       Col_1     Col_2     Col_3
# 0  0.341038  1.301513  0.072639
# 1 -0.671625 -0.529314 -0.721580
# 2  0.433398  1.600293 -1.136963
# 3 -0.606557 -1.133657  0.750222
# 4 -0.388710 -0.205927 -0.335404

# %% [markdown]
# # Min-Max Scale

# %%
# Your code
columns = df. columns
features = df

scaler = MinMaxScaler().fit(features.values)
features = scaler.transform(features.values)

scaled_features = pd.DataFrame(features, columns = columns)
scaled_features.head()
# Out:
#       Col_1     Col_2     Col_3
# 0  0.604662  0.891583  0.368585
# 1  0.295009  0.227237  0.126574
# 2  0.632904  1.000000  0.000000
# 3  0.314906  0.007941  0.575056
# 4  0.381520  0.344583  0.244248

# %% [markdown]
# # Robust Scaler
# ### Similar method to the Min-Max Scaler, but it instead uses the interquartile range, so that it is robust to outliers.
# ### xi-Q1(x)/Q3(x)-Q1(x)

# %%
# Your code
columns = df. columns
features = df

scaler = RobustScaler().fit(features.values)
features = scaler.transform(features.values)

scaled_features = pd.DataFrame(features, columns = columns)
scaled_features.head()
# Out:
#       Col_1     Col_2     Col_3
# 0  0.310100  0.937688  0.215177
# 1 -0.550545 -0.090836 -0.395085
# 2  0.388594  1.105537 -0.714257
# 3 -0.495244 -0.430345  0.735817
# 4 -0.310100  0.090836 -0.098355

# %% [markdown]
# # Feature Scaling
# ## Haberman's Survival with Pandas

# %%
import pandas as pd
columns = ["age","year","nodes","class"]
dataset = pd.read_csv('dataset/haberman.data', names=columns, header=None, sep=",")

df = pd.read_csv('dataset/haberman.data')

columns = ["age","year","nodes","class"]
df = pd.DataFrame(dataset, columns = columns)

df
# Out:
#      age  year  nodes  class
# 0     30    64      1      1
# 1     30    62      3      1
# 2     30    65      0      1
# 3     31    59      2      1
# 4     31    65      4      1
# ..   ...   ...    ...    ...
# 301   75    62      1      1
# 302   76    67      0      1
# 303   77    65      3      1
# 304   78    65      1      2
# 305   83    58      2      2
#
# [306 rows x 4 columns]

# %% [markdown]
# # In-Class Activity
#
# Apply the following feature scaling techniques to the Haberman's Survival dataset: Standard Scaler, Min-Max Scaler, and Robust Scaler. Ensure that you apply the scaling only to the attribute data and not to the class labels.

# %%
df.isnull().sum()
# Out:
# age      0
# nodes    0
# class    0
# dtype: int64

# %%
if 'year' in df.columns:
    df.drop(columns=['year'], inplace=True)
    print("\nDropped 'year' column")

print("\nDataset after dropping 'year':")
print(df.head())
print("\nDataset info:")
print(df.info())
# Out:
# Dataset after dropping 'year':
#    age  nodes  class
# 0   30      1      1
# 1   30      3      1
# 2   30      0      1
# 3   31      2      1
# 4   31      4      1
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     306 non-null    int64
#  1   nodes   306 non-null    int64
#  2   class   306 non-null    int64
# dtypes: int64(3)
# memory usage: 7.3 KB
# None

# %% [markdown]
# ### Applying Min-Max Scale

# %%
columns = df. columns
features = df

scaler = MinMaxScaler().fit(features.values)
features = scaler.transform(features.values)

scaled_features = pd.DataFrame(features, columns = columns)
scaled_features.head()
# Out:
#         age     nodes  class
# 0  0.000000  0.019231    0.0
# 1  0.000000  0.057692    0.0
# 2  0.000000  0.000000    0.0
# 3  0.018868  0.038462    0.0
# 4  0.018868  0.076923    0.0

# %% [markdown]
# ### Applying Standard Scaler

# %%
columns = df. columns
features = df

scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

scaled_features = pd.DataFrame(features, columns = columns)
scaled_features.head()
# Out:
#         age     nodes  class
# 0 -2.082140 -0.421592   -0.6
# 1 -2.082140 -0.142959   -0.6
# 2 -2.082140 -0.560909   -0.6
# 3 -1.989426 -0.282275   -0.6
# 4 -1.989426 -0.003642   -0.6

# %% [markdown]
# ### Applying Robust Scaler

# %%
columns = df. columns
features = df

scaler = RobustScaler().fit(features.values)
features = scaler.transform(features.values)

scaled_features = pd.DataFrame(features, columns = columns)
scaled_features.head()
# Out:
#         age  nodes  class
# 0 -1.313433   0.00    0.0
# 1 -1.313433   0.50    0.0
# 2 -1.313433  -0.25    0.0
# 3 -1.253731   0.25    0.0
# 4 -1.253731   0.75    0.0
