# %% [markdown]
# # Perceptron - Multiclass

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Load dataset from datasets.load_digits()

# %%
digits = datasets.load_digits()

# %%
print(f"Dataset shape: {digits.data.shape}")
print(f"Number of classes: {len(np.unique(digits.target))}")
# Out:
# Dataset shape: (1797, 64)
# Number of classes: 10

# %% [markdown]
# ### Split Features and Classes (X and y)

# %%
X = digits.data
y = digits.target

# %% [markdown]
# ### Visualize a sample

# %%
index = 7

print(digits.images[index])
# Out:
# [[ 0.  0.  7.  8. 13. 16. 15.  1.]
#  [ 0.  0.  7.  7.  4. 11. 12.  0.]
#  [ 0.  0.  0.  0.  8. 13.  1.  0.]
#  [ 0.  4.  8.  8. 15. 15.  6.  0.]
#  [ 0.  2. 11. 15. 15.  4.  0.  0.]
#  [ 0.  0.  0. 16.  5.  0.  0.  0.]
#  [ 0.  0.  9. 15.  1.  0.  0.  0.]
#  [ 0.  0. 13.  5.  0.  0.  0.  0.]]

# %%
print(f" Target = {digits.target[index]}")
image = digits.images[index]
plt.imshow(image, cmap = 'grey')
# Out:
#  Target = 7

# %% [markdown]
# ### Split Train and Test sets (70%, 30%)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ### Scale the features using StandardScaler()

# %%
scaler = StandardScaler()

X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
X_train_std[6]
# Out:
# array([ 0.        , -0.351631  , -0.45808439,  0.04687508,  0.97367535,
#         0.58531762, -0.40039639, -0.12994286, -0.05963551, -0.62194403,
#         0.32419864, -0.7549014 ,  0.5429138 ,  1.26365726,  1.95608213,
#        -0.13626673, -0.05337909,  0.12990411,  1.10566367, -0.37268168,
#        -1.15520185,  0.01567227,  3.07540111, -0.11219482, -0.03992024,
#        -0.75972517,  0.01461316,  1.19905678,  0.02133167,  0.9264589 ,
#        -0.08480321, -0.0489116 ,  0.        , -0.65101651, -1.20847626,
#        -0.82902122,  0.96187757,  0.57717259, -0.80964422,  0.        ,
#        -0.06972296, -0.52008392, -1.05597863,  0.56230651,  0.2045938 ,
#         1.36202846, -0.79087365, -0.09452778, -0.03937623, -0.41333112,
#        -1.15918408,  1.02247555, -1.44874506,  0.52405264, -0.76099399,
#        -0.21470714, -0.02821663, -0.31645972, -0.69093289,  0.89651196,
#         0.84643041, -0.13391112, -0.50587421, -0.19178564])

# %% [markdown]
# ### Create a Perceptron classifier

# %%
ppn = Perceptron(random_state=42)

# %% [markdown]
# ### Train the model

# %%
ppn. fit(X_train_std, y_train)
# Out:
# Perceptron(random_state=42)

# %% [markdown]
# ### Make predictions on the test set

# %%
y_pred = ppn.predict(X_test_std)

# %% [markdown]
# ### Measure the Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f" Model accuracy: {accuracy:.2f}")
# Out:
#  Model accuracy: 0.93

# %%
print(y_test[:20])
print(y_pred[:20])
# Out:
# [6 9 3 7 2 1 5 2 5 2 1 9 4 0 4 2 3 7 8 8]
# [6 9 3 7 2 2 5 2 5 2 1 6 4 0 4 2 3 7 8 8]
