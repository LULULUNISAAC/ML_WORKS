# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
#reading csv
f = pd.read_csv('myFile.csv', sep=";")

# %%
f
# Out:
#     Name  Age Student
# 0  Jonas   21     Yes
# 1  Maria   18      No
# 2  Peter   34      No
# 3  Joana   25     Yes

# %%
data = [[1,'Ackley',"Berrien Springs"], [2,'Luci','Rio de Janeiro'],[3, 'Ketlyn','West Palm Beach']]

f = pd.DataFrame(data,columns=['id','name','city'])

# %%
f
# Out:
#    id    name             city
# 0   1  Ackley  Berrien Springs
# 1   2    Luci   Rio de Janeiro
# 2   3  Ketlyn  West Palm Beach

# %%
f = pd.read_csv("pokemon.csv", sep=',')

# %%
f
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Selecting and filtering columns

# %%
columns = f[['Name','Attack','Defense']]
columns
# Out:
#                       Name  Attack  Defense
# 0                Bulbasaur      49       49
# 1                  Ivysaur      62       63
# 2                 Venusaur      82       83
# 3    VenusaurMega Venusaur     100      123
# 4               Charmander      52       43
# ..                     ...     ...      ...
# 795                Diancie     100      150
# 796    DiancieMega Diancie     160      110
# 797    HoopaHoopa Confined     110       60
# 798     HoopaHoopa Unbound     160       60
# 799              Volcanion     110      120
#
# [800 rows x 3 columns]

# %%
columns = f[['Name','Attack','Defense']]
columns
# Out:
#                       Name  Attack  Defense
# 0                Bulbasaur      49       49
# 1                  Ivysaur      62       63
# 2                 Venusaur      82       83
# 3    VenusaurMega Venusaur     100      123
# 4               Charmander      52       43
# ..                     ...     ...      ...
# 795                Diancie     100      150
# 796    DiancieMega Diancie     160      110
# 797    HoopaHoopa Confined     110       60
# 798     HoopaHoopa Unbound     160       60
# 799              Volcanion     110      120
#
# [800 rows x 3 columns]

# %%
columns = f [["Name"]],[["Attack"]],[["Speed"]]
columns
# Out:
# (                      Name
#  0                Bulbasaur
#  1                  Ivysaur
#  2                 Venusaur
#  3    VenusaurMega Venusaur
#  4               Charmander
#  ..                     ...
#  795                Diancie
#  796    DiancieMega Diancie
#  797    HoopaHoopa Confined
#  798     HoopaHoopa Unbound
#  799              Volcanion
#
#  [800 rows x 1 columns],
#  [['Attack']],
#  [['Speed']])

# %%
lines = f[f['Attack']>100]
lines
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# 12     9    BlastoiseMega Blastoise    Water     NaN    630   79     103
# 19    15      BeedrillMega Beedrill      Bug  Poison    495   65     150
# 39    34                   Nidoking   Poison  Ground    505   81     102
# ..   ...                        ...      ...     ...    ...  ...     ...
# 793  717                    Yveltal     Dark  Flying    680  126     131
# 796  719        DiancieMega Diancie     Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Creating a new column

# %%
f["Strength"] = f ["Attack"] + f ["Defense"] + f ["Speed"]
f
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
f["Power_Attack"] = f["Attack"]**2

# %%
f.rename(columns = {'Attack': 'Aggression'}, inplace=True)

# %%
f.drop(columns=['Power_Attack', "Strength"], inplace = True)
f
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Aggression  \
# 0      1              Bulbasaur    Grass  Poison    318  45          49
# 1      2                Ivysaur    Grass  Poison    405  60          62
# 2      3               Venusaur    Grass  Poison    525  80          82
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80         100
# 4      4             Charmander     Fire     NaN    309  39          52
# ..   ...                    ...      ...     ...    ...  ..         ...
# 795  719                Diancie     Rock   Fairy    600  50         100
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50         160
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80         110
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80         160
# 799  721              Volcanion     Fire   Water    600  80         110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
f = pd.DataFrame({
    'A':[10,20,30,40],
    'B':[5,4,8,2],
    'C':[100,200,300,400]
}, index=['L1','L2','L3','L4'])
f
# Out:
#      A  B    C
# L1  10  5  100
# L2  20  4  200
# L3  30  8  300
# L4  40  2  400

# %%
new_df = f['A']
new_df
# Out:
# L1    10
# L2    20
# L3    30
# L4    40
# Name: A, dtype: int64

# %%
new_df = f[['A','C']]
new_df
# Out:
#      A    C
# L1  10  100
# L2  20  200
# L3  30  300
# L4  40  400

# %%
f.iloc[0]
# Out:
# A     10
# B      5
# C    100
# Name: L1, dtype: int64

# %% [markdown]
# # DATA CLEANING

# %%
F = pd.DataFrame({
    'A': [1,2,None, 4],
    'B':[None,2,2,3],
    'C':['x','x','y','y']
})
F
# Out:
#      A    B  C
# 0  1.0  NaN  x
# 1  2.0  2.0  x
# 2  NaN  2.0  y
# 3  4.0  3.0  y

# %%
F.isnull()
# Out:
#        A      B      C
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False  False

# %%
F.dropna()
# Out:
#      A    B  C
# 1  2.0  2.0  x
# 3  4.0  3.0  y

# %%
F.fillna(0)
# Out:
#      A    B  C
# 0  1.0  0.0  x
# 1  2.0  2.0  x
# 2  0.0  2.0  y
# 3  4.0  3.0  y

# %% [markdown]
# # STATISTICS

# %%
df = pd.read_csv('house-prices.csv', sep=',')
df
# Out:
#      Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0       1  114300  1790         2          2       2    No         East
# 1       2  114200  2030         4          2       3    No         East
# 2       3  114800  1740         3          2       1    No         East
# 3       4   94700  1980         3          2       3    No         East
# 4       5  119800  2130         3          3       3    No         East
# ..    ...     ...   ...       ...        ...     ...   ...          ...
# 123   124  119700  1900         3          3       3   Yes         East
# 124   125  147900  2160         4          3       3   Yes         East
# 125   126  113500  2070         2          2       2    No        North
# 126   127  149900  2020         3          3       1    No         West
# 127   128  124600  2250         3          3       4    No        North
#
# [128 rows x 8 columns]

# %%
mean = df ['Price'].mean()
print(mean)

median = df['Price'].median()
print(median)

mode = df['Neighborhood'].mode()[0]
print(mode)

sum_=df['Price'].sum()
print(sum_)

std = df['Price'].std()
print(std)
# Out:
# 130427.34375
# 125950.0
# East
# 16694700
# 26868.770370734055

# %%
df.describe()
# Out:
#              Home          Price         SqFt    Bedrooms   Bathrooms  \
# count  128.000000     128.000000   128.000000  128.000000  128.000000
# mean    64.500000  130427.343750  2000.937500    3.023438    2.445312
# std     37.094474   26868.770371   211.572431    0.725951    0.514492
# min      1.000000   69100.000000  1450.000000    2.000000    2.000000
# 25%     32.750000  111325.000000  1880.000000    3.000000    2.000000
# 50%     64.500000  125950.000000  2000.000000    3.000000    2.000000
# 75%     96.250000  148250.000000  2140.000000    3.000000    3.000000
# max    128.000000  211200.000000  2590.000000    5.000000    4.000000
#
#            Offers
# count  128.000000
# mean     2.578125
# std      1.069324
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      3.000000
# max      6.000000
